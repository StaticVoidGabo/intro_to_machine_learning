# %% [markdown]
# ## Actividad 1
#
# Este notebook es un esqueleto que te ayudará a completar la Actividad 1. Modifícalo, y añade el texto y código necesario.

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
from sklearn import datasets
# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = [20, 10]
matplotlib.rcParams['font.size'] = 20

# %%
from sklearn.datasets import load_boston
data = load_boston()

X = data.data[:, [12]]
y = data.target

plt.scatter(X[:, 0], y, alpha=0.3)
plt.xlabel("% lower status of the population")
plt.ylabel("Median value of owner-occupied homes in $1000's")
plt.show()

# %% [markdown]
# Observando esta gráfica, la relación entre el estatus y el valor de la mediana de la casa no es lineal.
#
# __¿Cuál es el mejor modelo polinomial que puede modelizar esa muestra?__

# %%
## Codigo tuyo...

# %% [markdown]
# Ahora te aconsejamos que uses otras variables para poder predecir el valor de una casa.
#
# __¿Cuál es el mejor modelo multinlineal?__

# %%
## Codigo tuyo...

# %% [markdown]
# __Bonus__
#
# Calcula un modelo que sea la suma de un modelo polinomial y multinomial.

# %%
## Codigo tuyo...
