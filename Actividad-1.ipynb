# %% [markdown]
# ## Activividad 1
#
# Este notebook es un punto de partida de la Actividad 1. Modifica lo, añada texto y codigo.
#
# Puedes empezar de lo siguiente.

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
from sklearn import datasets
# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = [20, 10]
matplotlib.rcParams['font.size'] = 20

# %%
from sklearn.datasets import load_boston
data = load_boston()

X = data.data[:, [12]]
y = data.target

plt.scatter(X[:, 0], y, alpha=0.3)
plt.xlabel("% lower status of the population")
plt.ylabel("Median value of owner-occupied homes in $1000's")
plt.show()

# %% [markdown]
# Claramente esta relación no es lineal. ¿Cuál es el mejor modelo polinomial que puede modelizar esa muestra?

# %%
## Codigo tuyo...

# %% [markdown]
# Ahora busca el mejor modelo mulitlineal...

# %%
## Codigo tuyo...

# %% [markdown]
# __Bonus__ Mezcla un modelo mulitlineal y polinomial.

# %%
## Codigo tuyo...
